# %%
 Q1: Edge AI – Latency & Privacy
Answer:
Edge AI processes data locally on devices like smartphones or IoT sensors instead of sending it to remote servers (cloud). This reduces latency because data doesn't need to travel far, enabling faster responses in real-time. It also enhances privacy since sensitive data stays on the device.

Example:
In autonomous drones, Edge AI allows real-time object detection and navigation without needing to connect to the internet.

 Q2: Quantum AI vs Classical AI
Answer:
Classical AI uses traditional computing to solve problems step-by-step. Quantum AI uses quantum bits that can represent multiple states, enabling parallel computations. For optimization tasks like logistics or drug discovery, Quantum AI can explore more possibilities faster.

Industries benefiting:

Pharmaceutical (drug discovery)

Logistics (route optimization)

Finance (risk modeling)

 Q3: Human-AI Collaboration in Healthcare
Answer:
AI supports healthcare professionals by analyzing medical images, predicting patient outcomes, and suggesting treatments. Radiologists may rely on AI to detect anomalies faster, while nurses can use AI tools to monitor patient vitals and trigger alerts.

Societal impact:

Improved diagnosis accuracy

Reduced workload

Need for upskilling professionals

 Case Study: AI in Smart Cities – Traffic Management
Analysis:
Integrating AI with IoT improves urban sustainability by analyzing real-time traffic data to reduce congestion, emissions, and fuel use.

Two challenges:

Data Security – Real-time vehicle tracking raises privacy concerns.

Infrastructure Cost – Installing smart sensors and maintaining networks is expensive.

 Part 2: Practical Implementation 
⚙️ Task 1: Edge AI Prototype (Image Classifier)
Tools: TensorFlow, TensorFlow Lite (TFLite), Colab/Raspberry Pi

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.datasets import cifar10
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))


loss, acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", acc)


converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('recycler_model.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# Task 2: AI-Driven IoT Agriculture Concept
# Smart Agriculture Proposal (Summary)
#
# Sensors needed:
#
# Soil moisture sensor
#
# Temperature sensor
#
# Humidity sensor
#
# Light intensity sensor
#
# AI Model:
#
# Regression model (e.g., Random Forest) to predict crop yield from environmental data
#
# Data Flow Diagram:
#
# plaintext
# Copy
# Edit
# [Sensors] → [Microcontroller] → [Data Storage] → [AI Model] → [Crop Prediction Dashboard]
# ⚖️ Task 3: Ethics in Personalized Medicine
# Analysis (300 Words):
#
# AI models in personalized medicine can exhibit bias if trained on non-diverse datasets. For example, cancer treatment recommendations may not generalize well for underrepresented ethnic groups, leading to ineffective or harmful outcomes.
#
# Potential Bias Sources:
#
# Historical data lacking diversity
#
# Genomic datasets dominated by certain populations
#
# Algorithmic assumptions not reflecting minority physiology
#
# Fairness Strategies:
#
# Ensure training data includes various age, gender, and ethnic groups
#
# Apply fairness-aware machine learning techniques (e.g., reweighting, adversarial debiasing)
#
# Use interpretable models to detect bias in decision logic
#
# Conduct ongoing fairness audits post-deployment
#
#  Part 3: Futuristic Proposal (2030 AI)
# Title: AI-Powered Climate Control via Smart Forests
#
# Problem:
# Climate change leads to extreme heatwaves and droughts. There is a need for intelligent carbon capture and temperature regulation systems.
#
# AI Workflow:
#
# Data Inputs: Satellite imagery, air quality sensors, soil data
#
# Model Type: Reinforcement learning for forest maintenance & irrigation
#
# Output: Optimize CO₂ absorption, tree planting, and water use
#
# Risks:
#
# Privacy from surveillance sensors
#
# Dependence on AI systems
#
# Resource allocation fairness
#
# Benefits:
#
# Lower emissions
#
# Smarter ecosystem protection
#
# Sustainable cities

# %% [markdown]
#  Bonus Task: Quantum AI Simulation

# %%
# First, install the qiskit package
# !pip install qiskit

# Restart the kernel or use the following to import the newly installed package
import sys
import subprocess
import importlib

# Try to install qiskit if not already installed
try:
    import qiskit
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "qiskit"])
    importlib.invalidate_caches()
    import qiskit

# Then run your quantum circuit code
from qiskit import QuantumCircuit, Aer, execute
qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)
simulator = Aer.get_backend('qasm_simulator')
job = execute(qc, simulator, shots=100)
result = job.result()
counts = result.get_counts()
print(counts)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 11
#      10 try:
# ---> 11     import qiskit
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'qiskit'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 15
#      13     subprocess.check_call([sys.executable, "-m", "pip", "install", "qiskit"])
#      14     importlib.invalidate_caches()
# ---> 15     import qiskit
#      17 # Then run your quantum circuit code
#      18 from qiskit import QuantumCircuit, Aer, execute
#
# ...
